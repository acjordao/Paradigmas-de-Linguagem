# %% [markdown]
# <a href="https://colab.research.google.com/github/acjordao/Paradigmas-de-Linguagem/blob/main/Tarefa_Trilha_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Texto O Pequeno Príncipe
# ---

# %% [markdown]
# O livro O Pequeno Príncipe tem como uma das principais mensagens o amor.
#
# O livro é um dos meus favoritos e tem em sua história lindas reflexões apesar de ser considerado um livro infantil. De fato com essa tarefa consegui concluir que através da visualização de ocorrencias das palavras no texto é possível chegar a palavras chave do contexto do livro.
#
# Sendo elas príncipe e principezinho, duas formas de se referir ao protagonista da história, e que leva o leitor em suas aventuras no céu, sol e pelas estrelas outras palavras que ocorrrem de forma frequente no texto, outra palavra frequente no texto é raposa uma das persongens que é cativada pelo princípe durante seus dilemas e desenho também é uma das palavras que aparece com frequência e dentro do livro é um das formas em que o aviador e o príncipe conseguem se entender.
#
# Desta forma a palvra piloto, é um das palavras chave do texto que não aparecem no gráfico de ocorrências, dado que o limite mínimo de ocorrências delimitado por mim foi mínimo de 20 aparições, ademais as palavras que são encontradas com maior frequência transmitem ideias chave no texto.

# %% [markdown]
# ## Aquisição dos Dados

# %%
import urllib.request  
import nltk

texto = []

for line in urllib.request.urlopen('https://raw.githubusercontent.com/acjordao/Paradigmas-de-Linguagem/main/pequeno%20principe.txt'): 
     texto.append(line.decode('utf-8'))

# f = open('/kate_beckinsale.txt','r')    # para arquivos locais
# for line in f:
#    texto.append(line)

for i in range(len(texto)):
    texto[i] = texto[i].lower() # para unicidade
    texto[i] = texto[i].replace('.','')
    texto[i] = texto[i].replace(',','')
    texto[i] = texto[i].replace('(','')
    texto[i] = texto[i].replace(')','')
    texto[i] = texto[i].replace('?','')
    texto[i] = texto[i].replace('Descrição',' ')
    texto[i] = texto[i].replace('descrição',' ')
    texto[i] = texto[i].replace(' da ',' ')
    texto[i] = texto[i].replace('imagem',' ')
    texto[i] = texto[i].replace(' um ',' ')
    texto[i] = texto[i].replace(' de ',' ')
    texto[i] = texto[i].replace('que',' ')
    texto[i] = texto[i].replace(' a ',' ')
    texto[i] = texto[i].replace(' e ',' ')
    texto[i] = texto[i].replace(' o ',' ')
    texto[i] = texto[i].replace(' não ',' ')
    texto[i] = texto[i].replace(' é ',' ')
    texto[i] = texto[i].replace(' para ',' ')
    texto[i] = texto[i].replace(' se ',' ')
    texto[i] = texto[i].replace(' mas ',' ')
    texto[i] = texto[i].replace(' do ',' ')
    texto[i] = texto[i].replace(' as ',' ')
    texto[i] = texto[i].replace(' os ',' ')
    texto[i] = texto[i].replace(' és ',' ')
    texto[i] = texto[i].replace(' os ',' ')
    texto[i] = texto[i].replace(' das ',' ')
    texto[i] = texto[i].replace(' num ',' ')
    texto[i] = texto[i].replace(' nem ',' ')
    texto[i] = texto[i].replace(' nas ',' ')
    texto[i] = texto[i].replace(' nos ',' ')
    texto[i] = texto[i].replace(' uma ',' ')
    texto[i] = texto[i].replace('com',' ')
    texto[i] = texto[i].replace(' na ',' ')
    texto[i] = texto[i].replace(' no ',' ')

# %% [markdown]
# # Construção do Dicionário

# %%
mydict = {}                             # crie um dicionário vazio

for line in texto:

  line = line.lower()                   # converte para lower
  words = line.split()                  # separa cada palavra
#  print(words)

  for word in words:                      # para cada palavra em words
    if word not in mydict.keys():         # se palavra não está no dicionário 
      mydict[word] = 1                    # acrescenta a word com o valor 1
    else:                                 # se a entrada já existe 
      mydict[word] =  mydict[word] + 1    # apenas soma 1 ao valor já existente

print(mydict)
# Out:
# {'o': 163, 'pe': 134, 'príncipe': 107, 'autor:': 1, 'antoine': 1, 'saint-exupéry': 1, 'aquarelas': 2, 'autor': 1, 'tradução': 1, 'dom': 1, 'marcos': 1, 'barbosa': 1, 'título': 1, 'original:': 1, 'le': 14, 'petit': 1, 'prince': 1, 'a': 37, 'léon': 2, 'werth': 2, 'peço': 5, 'perdão': 3, 'às': 12, 'crianças': 8, 'por': 117, 'dedicar': 1, 'este': 9, 'livro': 8, 'pessoa': 9, 'grande': 29, 'tenho': 33, 'bom': 30, 'motivo:': 3, 'essa': 11, 'melhor': 7, 'amigo': 13, 'possuo': 9, 'outro': 14, 'capaz': 2, 'preender': 10, 'todas': 20, 'coisas': 8, 'até': 6, 'mesmo': 37, 'livros': 4, 'criança': 4, 'ainda': 26, 'um': 16, 'terceiro': 3, 'mora': 1, 'frança': 4, 'ela': 37, 'tem': 39, 'fome': 3, 'frio': 2, 'precisa': 1, 'consolo': 1, 'todos': 15, 'esses': 5, 'motivos': 1, 'bastam': 1, 'eu': 199, 'dedico': 1, 'então': 55, 'esse': 15, 'à': 53, 'já': 20, 'foi': 33, 'pessoas': 23, 'grandes': 27, 'foram': 2, 'dia': 53, '-': 736, 'poucas': 1, 'se': 8, 'lembram': 2, 'disso': 3, 'corrijo': 1, 'portanto': 7, 
# ...

# %% [markdown]
# # Exibição dos Resultados

# %%
import pandas as pd
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt

df = pd.DataFrame(mydict.items(),  columns=['word', 'count']).sort_values('count',ascending=False)
df = df[df['count'] > 20] # somente termos com mais de 20 ocorrências
# df = df.iloc[ np.int(len(df)/2) - 10 : np.int(len(df)/2) + 10 ] # para livros ou textos com muitos termos limita a um número mínimo de termos

plt.figure(figsize=(24,10))
mpl.style.use(['seaborn'])
sns.barplot(x=df.word,y=df['count'])
plt.xticks(rotation=90) 

plt.show()
